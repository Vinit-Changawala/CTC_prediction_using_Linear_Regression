# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Reading Excel file

# %%
df = pd.read_excel('./Data_file(1).xlsx')
df.head()
# Out:
#    S.No. College       Role  City type  Previous CTC  Previous job changes  \
# 0      1  Tier 1    Manager  Non-Metro         55523                     3
# 1      2  Tier 2  Executive      Metro         57081                     1
# 2      3  Tier 2  Executive      Metro         60347                     2
# 3      4  Tier 3  Executive      Metro         49010                     2
# 4      5  Tier 3  Executive      Metro         57879                     4
#
#    Graduation marks  Exp (Months)           CTC
# 0                66            19  71406.576531
# 1                84            18  68005.870631
# 2                52            28  76764.020277
# 3                81            33  82092.386880
# 4                74            32  73878.097729

# %% [markdown]
# ## Finding Missing Values

# %%
df.nunique()
# Out:
# S.No.                   1338
# College                    3
# Role                       2
# City type                  2
# Previous CTC            1308
# Previous job changes       4
# Graduation marks          51
# Exp (Months)              47
# CTC                     1338
# dtype: int64

# %%
df.shape
# Out:
# (1338, 9)

# %%
df.isnull().sum()
# Out:
# S.No.                   0
# College                 0
# Role                    0
# City type               0
# Previous CTC            0
# Previous job changes    0
# Graduation marks        0
# Exp (Months)            0
# CTC                     0
# dtype: int64

# %% [markdown]
# ## Pre-processing

# %%
clg_dummies = pd.get_dummies(df['College'])
clg_dummies.drop('Tier 3', axis=1, inplace=True)
clg_dummies.head()
# Out:
#    Tier 1  Tier 2
# 0       1       0
# 1       0       1
# 2       0       1
# 3       0       0
# 4       0       0

# %%
role_dummies = pd.get_dummies(df['Role'])
role_dummies.drop('Executive', axis=1, inplace=True)
role_dummies.head()
# Out:
#    Manager
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0

# %%
city_dummies = pd.get_dummies(df['City type'])
city_dummies.drop('Non-Metro', axis=1, inplace=True)
city_dummies.head()
# Out:
#    Metro
# 0      0
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df.drop(['S.No.','College', 'Role', 'City type'], axis=1, inplace=True)

# %%
new_df = pd.concat([clg_dummies, role_dummies, city_dummies,df], axis=1)
new_df.head()
# Out:
#    Tier 1  Tier 2  Manager  Metro  Previous CTC  Previous job changes  \
# 0       1       0        1      0         55523                     3
# 1       0       1        0      1         57081                     1
# 2       0       1        0      1         60347                     2
# 3       0       0        0      1         49010                     2
# 4       0       0        0      1         57879                     4
#
#    Graduation marks  Exp (Months)           CTC
# 0                66            19  71406.576531
# 1                84            18  68005.870631
# 2                52            28  76764.020277
# 3                81            33  82092.386880
# 4                74            32  73878.097729

# %%
new_df.drop('CTC', axis=1, inplace=True)
new_df.head()
# Out:
#    Tier 1  Tier 2  Manager  Metro  Previous CTC  Previous job changes  \
# 0       1       0        1      0         55523                     3
# 1       0       1        0      1         57081                     1
# 2       0       1        0      1         60347                     2
# 3       0       0        0      1         49010                     2
# 4       0       0        0      1         57879                     4
#
#    Graduation marks  Exp (Months)
# 0                66            19
# 1                84            18
# 2                52            28
# 3                81            33
# 4                74            32

# %% [markdown]
# ## Normalizing Data

# %%
from sklearn import preprocessing

val = new_df.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
val_scaled = min_max_scaler.fit_transform(val)
normalize_df = pd.DataFrame(val_scaled)
normalize_df.columns = ['College_T1', 'College_T2', 'Role_Manager', 'City_Metro', 
                        'previous CTC', 'previous job changes', 'Graduation marks', 'Exp']
normalize_df.head()
# Out:
#    College_T1  College_T2  Role_Manager  City_Metro  previous CTC  \
# 0         1.0         0.0           1.0         0.0      0.452897
# 1         0.0         1.0           0.0         1.0      0.490970
# 2         0.0         1.0           0.0         1.0      0.570783
# 3         0.0         0.0           0.0         1.0      0.293737
# 4         0.0         0.0           0.0         1.0      0.510471
#
#    previous job changes  Graduation marks       Exp
# 0              0.666667              0.62  0.021739
# 1              0.000000              0.98  0.000000
# 2              0.333333              0.34  0.217391
# 3              0.333333              0.92  0.326087
# 4              1.000000              0.78  0.304348

# %%
df.rename(columns = {'CTC':'Actual CTC'}, inplace = True)

# %% [markdown]
# ## Model Training

# %%
X = normalize_df
y = df['Actual CTC']

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Testing

# %%
test_df = pd.read_excel('./Test_data_file.xlsx')
test_df.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  Exp  \
# 0           0         55523                     3                66   19
# 1           1         57081                     1                84   18
# 2           1         60347                     2                52   28
# 3           1         49010                     2                81   33
# 4           1         57879                     4                74   32
#
#      Actual CTC  Predicted CTC
# 0  71406.576531            NaN
# 1  68005.870631            NaN
# 2  76764.020277            NaN
# 3  82092.386880            NaN
# 4  73878.097729            NaN

# %%
test_df = test_df.drop(['College', 'Role', 'City type', 'Predicted CTC'], axis='columns')
test_df.head()
# Out:
#    College_T1  College_T2  Role_Manager  City_Metro  previous CTC  \
# 0           1           0             1           0         55523
# 1           0           1             0           1         57081
# 2           0           1             0           1         60347
# 3           0           0             0           1         49010
# 4           0           0             0           1         57879
#
#    previous job changes  Graduation marks  Exp    Actual CTC
# 0                     3                66   19  71406.576531
# 1                     1                84   18  68005.870631
# 2                     2                52   28  76764.020277
# 3                     2                81   33  82092.386880
# 4                     4                74   32  73878.097729

# %%
new_test_df = test_df.copy(deep=True)
new_test_df.drop('Actual CTC', axis=1, inplace=True)
new_test_df.head()
# Out:
#    College_T1  College_T2  Role_Manager  City_Metro  previous CTC  \
# 0           1           0             1           0         55523
# 1           0           1             0           1         57081
# 2           0           1             0           1         60347
# 3           0           0             0           1         49010
# 4           0           0             0           1         57879
#
#    previous job changes  Graduation marks  Exp
# 0                     3                66   19
# 1                     1                84   18
# 2                     2                52   28
# 3                     2                81   33
# 4                     4                74   32

# %% [markdown]
# ## Normalizing Test Data

# %%
test_val = new_test_df.values #returns a numpy array
test_val_scaled = min_max_scaler.fit_transform(test_val)
test_normalize_df = pd.DataFrame(test_val_scaled)
test_normalize_df.columns = ['College_T1', 'College_T2', 'Role_Manager', 'City_Metro', 
                        'previous CTC', 'previous job changes', 'Graduation marks', 'Exp']
test_normalize_df.head()
# Out:
#    College_T1  College_T2  Role_Manager  City_Metro  previous CTC  \
# 0         1.0         0.0           1.0         0.0      0.452897
# 1         0.0         1.0           0.0         1.0      0.490970
# 2         0.0         1.0           0.0         1.0      0.570783
# 3         0.0         0.0           0.0         1.0      0.293737
# 4         0.0         0.0           0.0         1.0      0.510471
#
#    previous job changes  Graduation marks       Exp
# 0              0.666667              0.62  0.021739
# 1              0.000000              0.98  0.000000
# 2              0.333333              0.34  0.217391
# 3              0.333333              0.92  0.326087
# 4              1.000000              0.78  0.304348

# %% [markdown]
# ## Evaluation of Model

# %%
X_test = test_normalize_df
y_test = test_df['Actual CTC']

# %%
pred = model.predict(X_test)
prediction = pred.reshape(-1,1)
print(prediction)
# Out:
# [[86123.93814045]
#  [65789.54652723]
#  [69941.69030152]
#  ...
#  [64046.07444783]
#  [66223.22234282]
#  [90794.94065706]]

# %%
test_df['Actual CTC']
# Out:
# 0       71406.576531
# 1       68005.870631
# 2       76764.020277
# 3       82092.386880
# 4       73878.097729
#             ...
# 1333    69712.403655
# 1334    69298.750099
# 1335    66397.770686
# 1336    64044.382949
# 1337    83346.060961
# Name: Actual CTC, Length: 1338, dtype: float64

# %%
#Calculate root mean squared error to evaluate model performance
from sklearn.metrics import mean_squared_error
print('MSE : ', mean_squared_error(y_test,pred))
# Out:
# MSE :  61677937.045309596
